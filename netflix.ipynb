# %%
import numpy as np
import pandas as pd

# %%
credits_df=pd.read_csv("credits.csv")

# %%
credits_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
credits_df.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
titles_df=pd.read_csv("titles.csv")

# %%
titles_df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
titles_df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %%
#combing two dataset
# final_df=titles_df.concat(credits_df)\
final_df=pd.merge(credits_df,titles_df)

# %%
final_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role', 'title', 'type',
#        'description', 'release_year', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77801 entries, 0 to 77800
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   person_id             77801 non-null  int64
#  1   id                    77801 non-null  object
#  2   name                  77801 non-null  object
#  3   character             68029 non-null  object
#  4   role                  77801 non-null  object
#  5   title                 77800 non-null  object
#  6   type                  77801 non-null  object
#  7   description           77763 non-null  object
#  8   release_year          77801 non-null  int64
#  9   age_certification     46658 non-null  object
#  10  runtime               77801 non-null  int64
#  11  genres                77801 non-null  object
#  12  production_countries  77801 non-null  object
#  13  seasons               14710 non-null  float64
#  14  imdb_id               74302 non-null  object
# ...

# %%
#getting the top 5 value of the dataset
final_df.head()
# Out:
#    person_id       id             name                character   role  \
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 1  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 2  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 3  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 4  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
#
#    release_year age_certification  runtime              genres  \
# ...

# %%
#getting the last 5 value
final_df.tail()
# Out:
#        person_id         id                name     character      role  \
# 77796     736339  tm1059008    Adelaida Buscato     María Paz     ACTOR
# 77797     399499  tm1059008  Luz Stella Luengas  Karen Bayona     ACTOR
# 77798     373198  tm1059008         Inés Prieto         Fanny     ACTOR
# 77799     378132  tm1059008        Isabel Gaona        Cacica     ACTOR
# 77800    1950416  tm1059008      Julian Gaviria           NaN  DIRECTOR
#
#          title   type                                        description  \
# 77796  Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77797  Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77798  Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77799  Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77800  Lokillo  MOVIE  A controversial TV host and comedian who has b...
#
#        release_year age_certification  runtime      genres  \
# ...

# %%
final_df.rename(columns={"id":"id_tm"},inplace=True)

# %%
final_df.head()
# Out:
#    person_id    id_tm             name                character   role  \
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 1  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 2  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 3  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 4  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
#
#    release_year age_certification  runtime              genres  \
# ...

# %%
final_df["id_tm"]=final_df["id_tm"].str[2:]

# %%
final_df.head()
# Out:
#    person_id  id_tm             name                character   role  \
# 0       3748  84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  84618    Albert Brooks                      Tom  ACTOR
# 3       3739  84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 1  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 2  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 3  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 4  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
#
#    release_year age_certification  runtime              genres  \
# ...

# %%
#rename into first_name and last_name
final_df["Firstname"]=final_df["name"].str.split(" ").str[0]
final_df["Lastname"]=final_df["name"].str.split(" ").str[1]

# %%
final_df.head()
# Out:
#    person_id  id_tm             name                character   role  \
# 0       3748  84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  84618    Albert Brooks                      Tom  ACTOR
# 3       3739  84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 1  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 2  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 3  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 4  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
#
#    release_year age_certification  ...              genres  \
# ...

# %%
# final_df=final_df.drop(["Firsname","name"],axis=1)

# %%
final_df.head()
# Out:
#    person_id  id_tm             name                character   role  \
# 0       3748  84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  84618    Albert Brooks                      Tom  ACTOR
# 3       3739  84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 1  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 2  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 3  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 4  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
#
#    release_year age_certification  ...              genres  \
# ...

# %%
final_df.columns
# Out:
# Index(['person_id', 'id_tm', 'name', 'character', 'role', 'title', 'type',
#        'description', 'release_year', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'Firstname', 'Lastname'],
#       dtype='object')

# %%
final_df=final_df.drop(["name"],axis=1)

# %%
final_df.head()
# Out:
#    person_id  id_tm                character   role        title   type  \
# 0       3748  84618            Travis Bickle  ACTOR  Taxi Driver  MOVIE
# 1      14658  84618            Iris Steensma  ACTOR  Taxi Driver  MOVIE
# 2       7064  84618                      Tom  ACTOR  Taxi Driver  MOVIE
# 3       3739  84618  Matthew 'Sport' Higgins  ACTOR  Taxi Driver  MOVIE
# 4      48933  84618                    Betsy  ACTOR  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres production_countries  \
# ...

# %%
 #checing the unique val on the caracter col
# final_df["character"].value_counts :
# Actor=>1,Director=>2
final_df["role"]=final_df["role"].map({'ACOTR':'1','DIRECTOR':2})

# %%
final_df.columns
# Out:
# Index(['person_id', 'id_tm', 'character', 'role', 'title', 'type',
#        'description', 'release_year', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'Firstname', 'Lastname'],
#       dtype='object')

# %%
# final_df["role"].unique()

# %%
final_df["role"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77796    False
# 77797    False
# 77798    False
# 77799    False
# 77800    False
# Name: role, Length: 77801, dtype: bool

# %%
# final_df=final_df.drop(77800,axis=0)

# %%
# final_df["role"].isnull()

# %%
final_df.head()
# Out:
#    person_id  id_tm                character   role        title   type  \
# 0       3748  84618            Travis Bickle  ACTOR  Taxi Driver  MOVIE
# 1      14658  84618            Iris Steensma  ACTOR  Taxi Driver  MOVIE
# 2       7064  84618                      Tom  ACTOR  Taxi Driver  MOVIE
# 3       3739  84618  Matthew 'Sport' Higgins  ACTOR  Taxi Driver  MOVIE
# 4      48933  84618                    Betsy  ACTOR  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres production_countries  \
# ...

# %%
final_df["role"]=final_df["role"].map({"ACTOR":1,"DIRECTOR":2}) #1 for the ACTOR and 2 fro  director

# %%
# final_df["role"].isnull()
final_df.head()
# Out:
#    person_id  id_tm                character  role        title   type  \
# 0       3748  84618            Travis Bickle     1  Taxi Driver  MOVIE
# 1      14658  84618            Iris Steensma     1  Taxi Driver  MOVIE
# 2       7064  84618                      Tom     1  Taxi Driver  MOVIE
# 3       3739  84618  Matthew 'Sport' Higgins     1  Taxi Driver  MOVIE
# 4      48933  84618                    Betsy     1  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres production_countries  \
# ...

# %%
final_df["type"].unique()
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
#changing the type of movie as Movie=>1 and SHOW=>2
final_df['type']=final_df["type"].map({"MOVIE":1,"SHOW":2})

# %%
final_df.head()
# Out:
#    person_id  id_tm                character  role        title  type  \
# 0       3748  84618            Travis Bickle   NaN  Taxi Driver     1
# 1      14658  84618            Iris Steensma   NaN  Taxi Driver     1
# 2       7064  84618                      Tom   NaN  Taxi Driver     1
# 3       3739  84618  Matthew 'Sport' Higgins   NaN  Taxi Driver     1
# 4      48933  84618                    Betsy   NaN  Taxi Driver     1
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres production_countries  \
# ...

# %%
#no necessaRY FOR THE ODEL
final_df=final_df.drop(["description"],axis=1)

# %%
final_df.head()
# Out:
#    person_id  id_tm                character  role        title  type  \
# 0       3748  84618            Travis Bickle   NaN  Taxi Driver     1
# 1      14658  84618            Iris Steensma   NaN  Taxi Driver     1
# 2       7064  84618                      Tom   NaN  Taxi Driver     1
# 3       3739  84618  Matthew 'Sport' Higgins   NaN  Taxi Driver     1
# 4      48933  84618                    Betsy   NaN  Taxi Driver     1
#
#    release_year age_certification  runtime              genres  \
# 0          1976                 R      114  ['drama', 'crime']
# 1          1976                 R      114  ['drama', 'crime']
# 2          1976                 R      114  ['drama', 'crime']
# 3          1976                 R      114  ['drama', 'crime']
# 4          1976                 R      114  ['drama', 'crime']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      NaN  tt0075314         8.2    808582.0
# ...

# %%
# final_df.rename(colums={"release_year":"release_year(A.D)"},inplace=True)
final_df.rename(columns={"release_year":"release_year(A.D.)"},inplace=True)

# %%
final_df.head()
# Out:
#    person_id  id_tm                character  role        title  type  \
# 0       3748  84618            Travis Bickle   NaN  Taxi Driver     1
# 1      14658  84618            Iris Steensma   NaN  Taxi Driver     1
# 2       7064  84618                      Tom   NaN  Taxi Driver     1
# 3       3739  84618  Matthew 'Sport' Higgins   NaN  Taxi Driver     1
# 4      48933  84618                    Betsy   NaN  Taxi Driver     1
#
#    release_year(A.D.) age_certification  runtime              genres  \
# 0                1976                 R      114  ['drama', 'crime']
# 1                1976                 R      114  ['drama', 'crime']
# 2                1976                 R      114  ['drama', 'crime']
# 3                1976                 R      114  ['drama', 'crime']
# 4                1976                 R      114  ['drama', 'crime']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# ...

# %%
final_df['age_certification'].unique()
# Out:
# array(['R', 'PG', nan, 'TV-14', 'PG-13', 'TV-MA', 'TV-PG', 'TV-Y', 'TV-G',
#        'TV-Y7', 'G', 'NC-17'], dtype=object)

# %%
# final_df.rename(columns={"runtime","runtime(min)"},inplace=True)

# %%
final_df["genres"].unique()
# Out:
# array(["['drama', 'crime']",
#        "['drama', 'action', 'thriller', 'european']",
#        "['fantasy', 'action', 'comedy']", ...,
#        "['drama', 'animation', 'music']",
#        "['animation', 'family', 'scifi']",
#        "['documentation', 'music', 'reality']"], dtype=object)

# %%
final_df["production_countries"].unique()
# Out:
# array(["['US']", "['GB']", "['GB', 'US']", "['EG']", "['DE']", "['IN']",
#        "['SU', 'IN']", "['LB', 'CA', 'FR']", '[]', "['LB']",
#        "['DZ', 'EG']", "['CA', 'FR', 'LB']", "['US', 'GB']",
#        "['US', 'IT']", "['JP']", "['AR']", "['FR', 'EG']", "['FR', 'LB']",
#        "['CA', 'US']", "['US', 'FR']", "['JP', 'US']", "['US', 'CA']",
#        "['DE', 'US']", "['PE', 'US', 'BR']", "['IT', 'US', 'FR']",
#        "['IE', 'GB', 'DE', 'FR']", "['HK', 'US']", "['AU']", "['FR']",
#        "['DE', 'GH', 'GB', 'US', 'BF']", "['MX']", "['ES', 'AR']",
#        "['CO']", "['PS', 'US', 'FR', 'DE']", "['FR', 'NO', 'LB', 'BE']",
#        "['BE', 'FR', 'IT', 'LB']", "['TR']", "['IN', 'SU']", "['DK']",
#        "['CA']", "['DE', 'GB', 'US', 'BS', 'CZ']", "['MT', 'GB', 'US']",
#        "['AU', 'DE', 'GB', 'US']", "['US', 'JP']", "['BE', 'US']",
#        "['HK']", "['IT']", "['US', 'FR', 'DE', 'GB']",
#        "['GB', 'US', 'FR', 'DE']", "['IT', 'US']", "['US', 'ZA']",
# ...

# %%
final_df.columns
# Out:
# Index(['person_id', 'id_tm', 'character', 'role', 'title', 'type',
#        'release_year(A.D.)', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'Firstname', 'Lastname'],
#       dtype='object')

# %%
final_df["seasons"].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 77796    True
# 77797    True
# 77798    True
# 77799    True
# 77800    True
# Name: seasons, Length: 77801, dtype: bool

# %%
final_df=final_df.drop(["seasons"],axis=1)

# %%
final_df["imdb_id"]=final_df["imdb_id"].str[2:]

# %%
final_df.head()
# Out:
#    person_id  id_tm                character  role        title  type  \
# 0       3748  84618            Travis Bickle   NaN  Taxi Driver     1
# 1      14658  84618            Iris Steensma   NaN  Taxi Driver     1
# 2       7064  84618                      Tom   NaN  Taxi Driver     1
# 3       3739  84618  Matthew 'Sport' Higgins   NaN  Taxi Driver     1
# 4      48933  84618                    Betsy   NaN  Taxi Driver     1
#
#    release_year(A.D.) age_certification  runtime              genres  \
# 0                1976                 R      114  ['drama', 'crime']
# 1                1976                 R      114  ['drama', 'crime']
# 2                1976                 R      114  ['drama', 'crime']
# 3                1976                 R      114  ['drama', 'crime']
# 4                1976                 R      114  ['drama', 'crime']
#
#   production_countries imdb_id  imdb_score  imdb_votes  tmdb_popularity  \
# ...

# %%
final_df["imdb_score"].unique()
# Out:
# array([8.2, 7.7, 8.8, 8. , 5.8, 7.5, 7.3, 8.1, 6.2, 7.2, 2.1, 7.6, 7.4,
#        6.7, 6.1, 6.4, 5.1, 6.5, 6.6, 7.8, 4.6, 4.4, 8.9, 8.7, 8.3, 6.9,
#        7.1, 4.9, 7.9, 5.9, 7. , 6. , 5.6, nan, 5.4, 6.3, 5.2, 3.8, 4.8,
#        8.4, 8.6, 8.5, 4.5, 6.8, 9. , 5.5, 5. , 9.5, 9.3, 5.7, 4. , 3.9,
#        3.6, 4.1, 5.3, 4.7, 2.9, 3.4, 4.3, 2. , 4.2, 3.2, 3.5, 1.7, 9.2,
#        3. , 3.7, 1.9, 2.8, 1.5, 2.7, 9.1, 3.3, 2.3, 3.1, 2.2, 1.6, 2.5,
#        2.6])

# %%
#dropping the personal id
# final_df=final_df.drop(["persoan_id"],axis=0)

# %%
final_df.columns
# Out:
# Index(['person_id', 'id_tm', 'character', 'role', 'title', 'type',
#        'release_year(A.D.)', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'imdb_id', 'imdb_score', 'imdb_votes',
#        'tmdb_popularity', 'tmdb_score', 'Firstname', 'Lastname'],
#       dtype='object')

# %%
# EDA is done
